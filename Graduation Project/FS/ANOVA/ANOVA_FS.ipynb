# %%
# Feature Selection with Univariate Statistical Tests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
import seaborn as sns
from sklearn import metrics 
from sklearn.metrics import roc_curve
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
#---------------------used classifiers 

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier

from sklearn.experimental import enable_hist_gradient_boosting  
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
#-------------------------
import warnings
import sys
sys.path
warnings.filterwarnings('ignore')

# %% [markdown]
# # FS.1 - Loading Data

# %%
#Loading data into dataframe

data = pd.read_csv("C:\\Users\\Smart Tablets\\Desktop\\KEYSTROKE AUTHENTICATION PROJECT//DS//KEYSTROKES.csv")
data.head()
df=data

# %% [markdown]
# # FS.2 - Data Splitting

# %%
X=df.drop(['subject'],axis=1)
y=df['subject']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
X_train.shape, X_test.shape , y_train.shape,y_test.shape
# Out:
# ((17920, 83), (4480, 83), (17920,), (4480,))

# %% [markdown]
# # FS.3- ANOVA K_BEST

# %%
import time

#####
def run_randomForest(X_train, X_test, y_train, y_test):
    start_time = time.time()
    clf = RandomForestClassifier(n_estimators=10, random_state=0, n_jobs=-1)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print('Accuracy: ', accuracy_score(y_test, y_pred),"---TIME = %s seconds ---" % (time.time() - start_time))

for index in range(1, 84):
    sel = SelectKBest(score_func=f_classif, k=index)
    fit = sel.fit(X,y)
    X_train_rfe = sel.transform(X_train)
    X_test_rfe = sel.transform(X_test)
    print('Selected Feature: ', index)
    run_randomForest(X_train_rfe, X_test_rfe, y_train, y_test)
    print()
# Out:
# Selected Feature:  1
# Accuracy:  0.11272321428571429 ---TIME = 0.29771971702575684 seconds ---
#
# Selected Feature:  2
# Accuracy:  0.3734375 ---TIME = 0.2469191551208496 seconds ---
#
# Selected Feature:  3
# Accuracy:  0.5334821428571429 ---TIME = 0.22189927101135254 seconds ---
#
# Selected Feature:  4
# Accuracy:  0.6118303571428572 ---TIME = 0.3561999797821045 seconds ---
#
# Selected Feature:  5
# Accuracy:  0.6600446428571428 ---TIME = 0.3691108226776123 seconds ---
#
# Selected Feature:  6
# Accuracy:  0.6955357142857143 ---TIME = 0.3666982650756836 seconds ---
#
# Selected Feature:  7
# Accuracy:  0.7082589285714286 ---TIME = 0.32639503479003906 seconds ---
#
# Selected Feature:  8
# Accuracy:  0.7399553571428571 ---TIME = 0.3336937427520752 seconds ---
#
# Selected Feature:  9
# Accuracy:  0.7662946428571429 ---TIME = 0.4492354393005371 seconds ---
#
# Selected Feature:  10
# Accuracy:  0.7680803571428572 ---TIME = 0.41800928115844727 seconds ---
#
# ...

# %% [markdown]
# # ANOVA BEST RESULT ACC= 99.04  with 76 Feature

# %%
index=76
sel = SelectKBest(score_func=f_classif, k=index)
fit = sel.fit(X,y)
X_train_rfe = sel.transform(X_train)
X_test_rfe = sel.transform(X_test)
print('Selected Feature: ', index)
run_randomForest(X_train_rfe, X_test_rfe, y_train, y_test)
# Out:
# Selected Feature:  76
# Accuracy:  0.9904017857142857 ---TIME = 0.8776345252990723 seconds ---
